# %%
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
import pandas as pd
from scipy import integrate

# %%
datos3000 = pd.read_csv('Temp_3000.csv', usecols=[0,1])
datos3000.dropna(inplace = True)

x3000 = datos3000['distancia'].to_list() #to convert data in a col to list
y3000 = datos3000['intensidad'].to_list()

area1 = integrate.trapz(y3000, x3000)
area1
# Out:
# 4021249.012787998

# %%
plt.figure(figsize=(5, 3), dpi=300)

plt.xlabel(r'Longitud de onda (m)')
plt.ylabel(r"Radiancia espectral ($\frac{W}{\mu m m^{2}}$)")


plt.plot(x3000, y3000)
plt.show()  #

# %%
datos4000 = pd.read_csv('Temp_4000.csv', usecols=[0,1])
datos4000.dropna(inplace = True)

#datos4000

x4000 = datos4000['distancia'].to_list() #to convert data in a col to list
y4000 = datos4000['intensidad'].to_list()

#x4000
area2 = integrate.trapz(y4000, x4000)
area2
# Out:
# 13497362.08337141

# %%
plt.figure(figsize=(5, 3), dpi=300)

plt.xlabel(r'Longitud de onda (m)')
plt.ylabel(r"Radiancia espectral ($\frac{W}{\mu m m^{2}}$)")


plt.plot(x4000, y4000)
plt.show()  #

# %%
datos5500 = pd.read_csv('Temp_5500.csv', usecols=[0,1])
datos5500.dropna(inplace = True)

x5500 = datos5500['distancia'].to_list() #to convert data in a col to list
y5500 = datos5500['intensidad'].to_list()

area3 = integrate.trapz(y5500, x5500)
area3
# Out:
# 49809168.726570226

# %%
plt.figure(figsize=(5, 3), dpi=300)

plt.xlabel(r'Longitud de onda (m)')
plt.ylabel(r"Radiancia espectral ($\frac{W}{\mu m m^{2}}$)")


plt.plot(x5500, y5500)
plt.show()  #

# %%
datos10000 = pd.read_csv('Temp_10000.csv', usecols=[0,1])
datos10000.dropna(inplace = True)

x10000 = datos10000['distancia'].to_list() #to convert data in a col to list
y10000 = datos10000['intensidad'].to_list()

area4 = integrate.trapz(y10000, x10000)
area4
# Out:
# 555343825.2683302

# %%
plt.figure(figsize=(5, 3), dpi=300)

plt.xlabel(r'Longitud de onda (m)')
plt.ylabel(r"Radiancia espectral ($\frac{W}{\mu m m^{2}}$)")

plt.plot(x10000, y10000)
plt.show()
